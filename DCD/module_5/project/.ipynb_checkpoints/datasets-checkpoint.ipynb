# %%
import pandas as pd

datasets = pd.read_excel("datasets.xlsx")
datasets
# Out:
#                      dataset                   Tipo        Link  \
# 0                 nba-raptor           Estructurado  M4_Minería
# 1               Forest fires           Estructurado  M4_Minería
# 2                      Crime           Estructurado  M4_Minería
# 3        Student performance           Estructurado  M4_Minería
# 4              Online retail           Estructurado  M4_Minería
# 5                Gas Turbine           Estructurado  M4_Minería
# 6                 Mississipi           Estructurado  M4_Minería
# 7              SeattleHouses           Estructurado  M4_Minería
# 8                  Glassdoor           Estructurado  M4_Minería
# 9                     Airbnb           Estructurado  M4_Minería
# 10                 mushrooms           Estructurado       Nuevo
# 11                 Películas           Estructurado       Nuevo
# 12       Transmilenio Bogotá           Estructurado       Nuevo
# 13  Enfermedades del Corazón           Estructurado       Nuevo
# ...
