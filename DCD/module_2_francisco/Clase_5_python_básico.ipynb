# %% [markdown]
# <a href="https://colab.research.google.com/github/gtzambranop/UN_2020_2/blob/DCD/DCD/module_2_francisco/Clase_5_python_b%C3%A1sico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! wget https://www.dropbox.com/s/kc98g3pjcp8trba/MCU2.csv
# Out:
# --2020-09-27 05:52:01--  https://www.dropbox.com/s/kc98g3pjcp8trba/MCU2.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/kc98g3pjcp8trba/MCU2.csv [following]
# --2020-09-27 05:52:02--  https://www.dropbox.com/s/raw/kc98g3pjcp8trba/MCU2.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com/cd/0/inline/BALDX1cRE4T1buSDcnfMR1HSpGwGhzhlupkD4uK97GVbvpxTpzmcdXUMOtNCw3qIPZjN8TtIAb1ybHQEQAGXWP8ZjU4t_6Q2MDWG_oRLrZ5EG8MokCsK1KdufN9HsmJDO5g/file# [following]
# --2020-09-27 05:52:02--  https://uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com/cd/0/inline/BALDX1cRE4T1buSDcnfMR1HSpGwGhzhlupkD4uK97GVbvpxTpzmcdXUMOtNCw3qIPZjN8TtIAb1ybHQEQAGXWP8ZjU4t_6Q2MDWG_oRLrZ5EG8MokCsK1KdufN9HsmJDO5g/file
# Resolving uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com (uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com (uc45f760b14f5f4e3183929e9a75.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1890 (1.8K) [text/plain]
# Saving to: ‘MCU2.csv.1’
#
# MCU2.csv.1          100%[===================>]   1.85K  --.-KB/s    in 0s
#
# 2020-09-27 05:52:02 (267 MB/s) - ‘MCU2.csv.1’ saved [1890/1890]

# %%
! head -n 5 MCU2.csv
# Out:
# Iron Man,The Incredible Hulk,Iron Man 2,Thor,Capitán América: el primer vengador,The Avengers,Iron Man 3,Thor: The Dark World,Captain America: The Winter Soldier,Guardianes de la Galaxia,Avengers: Age of Ultron,Ant-Man,Captain America: Civil War,Doctor Strange,Guardianes de la Galaxia Vol. 2,Spider-Man: Homecoming,Thor: Ragnarok,Black Panther,Avengers: Infinity War,Ant-Man and The Wasp
# 17,12,14,13,11,18,4,5,6,16,17,10,19,17,7,6,10,8,20,9
# 8,1,7,1,7,8,7,3,8,9,7,9,8,9,9,9,9,8,9,9
# 20,13,6,7,11,19,9,5,17,20,20,17,20,10,6,6,4,17,18,8
# 18,10,19,15,5,16,18,16,8,18,,,18,,16,10,,,17,

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (1.0.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %%
import pandas as pd
df_mcu = pd.read_csv('MCU2.csv')

# %%
df_mcu
# Out:
#     Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0       17.0                 12.0  ...                      20                   9.0
# 1        8.0                  1.0  ...                       9                   9.0
# 2       20.0                 13.0  ...                      18                   8.0
# 3       18.0                 10.0  ...                      17                   NaN
# 4        NaN                  3.0  ...                      16                   NaN
# 5       13.0                  NaN  ...                      20                   NaN
# 6       17.0                 13.0  ...                      20                  19.0
# 7       10.0                 11.0  ...                      20                  17.0
# 8       14.0                  8.0  ...                      20                   5.0
# 9       16.0                 13.0  ...                      20                  14.0
# 10      15.0                  1.0  ...                      16                   7.0
# 11       1.0                  1.0  ...                       1                   1.0
# 12      11.0                  2.0  ...                      18                  13.0
# 13      15.0                 12.0  ...                      20                  16.0
# 14      16.0                  5.0  ...                      20                   9.0
# 15      15.0                 10.0  ...                      20                  13.0
# 16       3.0                  5.0  ...                      16                   NaN
# 17       NaN                  2.0  ...                       4                   NaN
# 18       9.0                  1.0  ...                      20                   9.0
# 19      18.0                 10.0  ...                      18                  18.0
# 20      15.0                 10.0  ...                      16                  14.0
# 21      18.0                 10.0  ...                      20                   NaN
# 22      13.0                  2.0  ...                      17                   NaN
# 23      18.0                  1.0  ...                      15                   NaN
# 24      15.0                  1.0  ...                      20                   NaN
# 25      17.0                  NaN  ...                      20                   NaN
# 26      17.0                  NaN  ...                      20                  13.0
# 27       NaN                  NaN  ...                      17                  18.0
# 28       7.0                  2.0  ...                      19                  11.0
# 29      10.0                  8.0  ...                      17                  13.0
#
# [30 rows x 20 columns]

# %%
df_mcu.shape
# Out:
# (30, 20)

# %%
df_mcu2 = df_mcu.dropna()
df_mcu2.shape
# Out:
# (15, 20)

# %%
dc_mean = df_mcu.mean().to_dict()
df_mcu3 = df_mcu.fillna(dc_mean)
df_mcu3.head()
# Out:
#     Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0  17.000000                 12.0  ...                      20                   9.0
# 1   8.000000                  1.0  ...                       9                   9.0
# 2  20.000000                 13.0  ...                      18                   8.0
# 3  18.000000                 10.0  ...                      17                  11.8
# 4  13.555556                  3.0  ...                      16                  11.8
#
# [5 rows x 20 columns]

# %%
df_mcu.mean(axis=0)
df_mcu.mean(axis=1)
# Out:
# 0     11.950000
# 1      7.250000
# 2     12.650000
# 3     14.571429
# 4      9.833333
# 5     12.277778
# 6     18.200000
# 7     10.500000
# 8     10.500000
# 9     14.450000
# 10    11.900000
# 11     1.050000
# 12    10.500000
# 13    14.550000
# 14    10.500000
# 15    12.526316
# 16    11.333333
# 17     2.900000
# 18    11.111111
# 19    13.850000
# 20    13.916667
# 21    14.526316
# 22    11.000000
# 23    10.736842
# 24    10.894737
# 25    15.250000
# 26    12.263158
# 27    13.857143
# 28    10.500000
# 29    12.500000
# dtype: float64

# %%
dc_median = df_mcu.quantile(.5).to_dict()
df_mcu4 = df_mcu.fillna(dc_median)
df_mcu4.head()
# Out:
#    Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0      17.0                 12.0  ...                      20                   9.0
# 1       8.0                  1.0  ...                       9                   9.0
# 2      20.0                 13.0  ...                      18                   8.0
# 3      18.0                 10.0  ...                      17                  13.0
# 4      15.0                  3.0  ...                      16                  13.0
#
# [5 rows x 20 columns]

# %%
! pip install impyute
# Out:
# Requirement already satisfied: impyute in /usr/local/lib/python3.6/dist-packages (0.0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from impyute) (1.18.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from impyute) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from impyute) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->impyute) (0.16.0)

# %%
#import sys
from impyute.imputation.cs import fast_knn
#sys.setrecursionlimit(100000) 

df_mcu5 = fast_knn(df_mcu.values, k=10) #Recibe y retorna como parámetro un array de numpy
df_mcu5 = pd.DataFrame(df_mcu5, columns=df_mcu.columns)
df_mcu5.head()
# Out:
#     Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0  17.000000                 12.0  ...                    20.0              9.000000
# 1   8.000000                  1.0  ...                     9.0              9.000000
# 2  20.000000                 13.0  ...                    18.0              8.000000
# 3  18.000000                 10.0  ...                    17.0             13.518933
# 4  12.858728                  3.0  ...                    16.0             11.475344
#
# [5 rows x 20 columns]

# %%
from impyute.imputation.cs import mice

df_mcu6 = mice(df_mcu.values) # Ver docstring
df_mcu6 = pd.DataFrame(df_mcu6, columns=df_mcu.columns)
df_mcu6.head()
# Out:
#     Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0  17.000000                 12.0  ...                    20.0              9.000000
# 1   8.000000                  1.0  ...                     9.0              9.000000
# 2  20.000000                 13.0  ...                    18.0              8.000000
# 3  18.000000                 10.0  ...                    17.0             30.785275
# 4  13.555556                  3.0  ...                    16.0              0.796626
#
# [5 rows x 20 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df_mcu6)
df_scaled = scaler.transform(df_mcu6)
df_scaled = pd.DataFrame(df_scaled, columns=df_mcu.columns)
df_scaled.head()
# Out:
#    Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0  0.842105             0.916667  ...                1.000000              0.284634
# 1  0.368421             0.000000  ...                0.421053              0.284634
# 2  1.000000             1.000000  ...                0.894737              0.251796
# 3  0.894737             0.750000  ...                0.842105              1.000000
# 4  0.660819             0.166667  ...                0.789474              0.015258
#
# [5 rows x 20 columns]

# %%
import numpy as np
import pandas as pd

array = np.arange(1000, 10000)
array2 = np.arange(100)
mat1 = np.random.choice(array, 450).reshape(30,15)
mat2 = np.random.choice(array2, 90).reshape(30,3)

concat = np.concatenate((mat1, mat2), axis=1)
np.random.shuffle(np.transpose(concat))

bool_mat = np.random.choice(np.array([True, True, False]), 18*30).reshape(30,18)

concat[bool_mat] = 0

df1 = pd.DataFrame(concat)
df1
# Out:
#       0     1     2     3     4     5   ...  12    13    14    15  16  17
# 0   8770     0     0  1007  1165  1728  ...   0  9483  3883     0   0   0
# 1      0  9223     0     0     0     0  ...   0  7097     0     0   0   0
# 2   7019     0  4988     0  8493     0  ...  52  1532     0     0  95  83
# 3   6008     0     0     0  8325     0  ...   0     0  5795     0   0  26
# 4   4266     0     0     0  8062     0  ...  15     0     0  2664   0  94
# 5      0     0  5903     0     0     0  ...   0     0  7963     0   0  63
# 6      0     0  2662     0     0     0  ...   0     0  9919     0   0   4
# 7   8324     0  6583  5957     0     0  ...   0     0  2291     0   0   0
# 8   2051  4191     0     0     0  2464  ...  80     0     0     0  84   0
# 9      0     0     0     0     0     0  ...  40     0  9217     0   0  39
# 10  1649     0  6654  7812     0     0  ...   0  7449     0     0  97   0
# 11     0     0  1414     0  2490     0  ...   0  5085     0     0   0  39
# 12     0     0     0     0     0  2465  ...   0     0     0     0   0  17
# 13     0     0  1705  8936  4276  8928  ...  56  6722  2814  9765   0  83
# 14     0     0     0     0     0     0  ...  97     0  8971  2782   0   0
# 15     0  9462     0     0     0  9080  ...  45     0  8455  7844  52  41
# 16  2620  5395     0     0     0     0  ...  89     0     0     0  63   0
# 17     0     0     0  3951     0     0  ...   0     0     0     0   0   0
# 18     0  5401  4045     0  9877     0  ...  45  4554  2843     0  54   0
# 19     0     0  7382     0     0  2848  ...   0     0     0     0   8   0
# 20     0     0     0  5903     0  6870  ...  45     0  1736     0   0  93
# 21  3832  7227     0     0  3793     0  ...   0     0     0     0   0   0
# 22  3530     0     0  1306  4698  4542  ...  42  1281     0  1064   0   0
# 23     0     0     0     0     0  5338  ...   0     0  1442     0   0   0
# 24  7359  2894     0  7059     0     0  ...   0     0  6458  4315   0  96
# 25     0  8182     0     0     0  6658  ...   0     0     0     0  15   0
# 26     0     0     0     0     0  4626  ...   0     0     0  5429  77  75
# 27     0  1809     0  4414     0     0  ...  15     0  9925  7212   0  56
# 28  9362     0     0     0     0     0  ...   0     0     0     0  58   0
# 29     0     0     0     0  2757     0  ...   0     0     0     0   0   0
#
# [30 rows x 18 columns]

# %%
from sklearn.preprocessing import MaxAbsScaler

scaler = MaxAbsScaler()
scaler.fit(df1)
scaled = scaler.transform(df1)
df1_scaled = pd.DataFrame(scaled)
df1_scaled
# Out:
#           0         1         2   ...        15        16        17
# 0   0.936766  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 1   0.000000  0.974741  0.000000  ...  0.000000  0.000000  0.000000
# 2   0.749733  0.000000  0.675698  ...  0.000000  0.979381  0.864583
# 3   0.641743  0.000000  0.000000  ...  0.000000  0.000000  0.270833
# 4   0.455672  0.000000  0.000000  ...  0.272811  0.000000  0.979167
# 5   0.000000  0.000000  0.799648  ...  0.000000  0.000000  0.656250
# 6   0.000000  0.000000  0.360607  ...  0.000000  0.000000  0.041667
# 7   0.889126  0.000000  0.891764  ...  0.000000  0.000000  0.000000
# 8   0.219077  0.442930  0.000000  ...  0.000000  0.865979  0.000000
# 9   0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.406250
# 10  0.176138  0.000000  0.901382  ...  0.000000  1.000000  0.000000
# 11  0.000000  0.000000  0.191547  ...  0.000000  0.000000  0.406250
# 12  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.177083
# 13  0.000000  0.000000  0.230967  ...  1.000000  0.000000  0.864583
# 14  0.000000  0.000000  0.000000  ...  0.284895  0.000000  0.000000
# 15  0.000000  1.000000  0.000000  ...  0.803277  0.536082  0.427083
# 16  0.279855  0.570175  0.000000  ...  0.000000  0.649485  0.000000
# 17  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 18  0.000000  0.570810  0.547954  ...  0.000000  0.556701  0.000000
# 19  0.000000  0.000000  1.000000  ...  0.000000  0.082474  0.000000
# 20  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.968750
# 21  0.409314  0.763792  0.000000  ...  0.000000  0.000000  0.000000
# 22  0.377056  0.000000  0.000000  ...  0.108961  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
# 24  0.786050  0.305855  0.000000  ...  0.441884  0.000000  1.000000
# 25  0.000000  0.864722  0.000000  ...  0.000000  0.154639  0.000000
# 26  0.000000  0.000000  0.000000  ...  0.555965  0.793814  0.781250
# 27  0.000000  0.191186  0.000000  ...  0.738556  0.000000  0.583333
# 28  1.000000  0.000000  0.000000  ...  0.000000  0.597938  0.000000
# 29  0.000000  0.000000  0.000000  ...  0.000000  0.000000  0.000000
#
# [30 rows x 18 columns]

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
scaler.fit(df1)
scaled = scaler.transform(df1)
pd.DataFrame(scaled)
# Out:
#           0         1         2   ...         15        16        17
# 0   2.334620  0.000000  0.000000  ...   0.000000  0.000000  0.000000
# 1   0.000000  3.516538  0.000000  ...   0.000000  0.000000  0.000000
# 2   1.868495  0.000000  3.055904  ...   0.000000  2.222222  1.588517
# 3   1.599361  0.000000  0.000000  ...   0.000000  0.000000  0.497608
# 4   1.135632  0.000000  0.000000  ...   3.338346  0.000000  1.799043
# 5   0.000000  0.000000  3.616480  ...   0.000000  0.000000  1.205742
# 6   0.000000  0.000000  1.630878  ...   0.000000  0.000000  0.076555
# 7   2.215892  0.000000  4.033083  ...   0.000000  0.000000  0.000000
# 8   0.545987  1.597941  0.000000  ...   0.000000  1.964912  0.000000
# 9   0.000000  0.000000  0.000000  ...   0.000000  0.000000  0.746411
# 10  0.438972  0.000000  4.076581  ...   0.000000  2.269006  0.000000
# 11  0.000000  0.000000  0.866289  ...   0.000000  0.000000  0.746411
# 12  0.000000  0.000000  0.000000  ...   0.000000  0.000000  0.325359
# 13  0.000000  0.000000  1.044570  ...  12.236842  0.000000  1.588517
# 14  0.000000  0.000000  0.000000  ...   3.486216  0.000000  0.000000
# 15  0.000000  3.607664  0.000000  ...   9.829574  1.216374  0.784689
# 16  0.697458  2.057001  0.000000  ...   0.000000  1.473684  0.000000
# 17  0.000000  0.000000  0.000000  ...   0.000000  0.000000  0.000000
# 18  0.000000  2.059289  2.478174  ...   0.000000  1.263158  0.000000
# 19  0.000000  0.000000  4.522592  ...   0.000000  0.187135  0.000000
# 20  0.000000  0.000000  0.000000  ...   0.000000  0.000000  1.779904
# 21  1.020098  2.755505  0.000000  ...   0.000000  0.000000  0.000000
# 22  0.939705  0.000000  0.000000  ...   1.333333  0.000000  0.000000
# 23  0.000000  0.000000  0.000000  ...   0.000000  0.000000  0.000000
# 24  1.959004  1.103422  0.000000  ...   5.407268  0.000000  1.837321
# 25  0.000000  3.119626  0.000000  ...   0.000000  0.350877  0.000000
# 26  0.000000  0.000000  0.000000  ...   6.803258  1.801170  1.435407
# 27  0.000000  0.689734  0.000000  ...   9.037594  0.000000  1.071770
# 28  2.492213  0.000000  0.000000  ...   0.000000  1.356725  0.000000
# 29  0.000000  0.000000  0.000000  ...   0.000000  0.000000  0.000000
#
# [30 rows x 18 columns]

# %%
a = 1e6
print(a)

for i in np.arange(1e6):
    a = a + 1e-6
    
print(a)
# Out:
# 1000000.0
# 1000001.0000076145

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(df_mcu6)
df_scaled = scaler.transform(df_mcu6)
df_scaled = pd.DataFrame(df_scaled, columns=df_mcu.columns)
df_scaled.head()
# Out:
#    Iron Man  The Incredible Hulk  ...  Avengers: Infinity War  Ant-Man and The Wasp
# 0  0.842105             0.916667  ...                1.000000              0.284634
# 1  0.368421             0.000000  ...                0.421053              0.284634
# 2  1.000000             1.000000  ...                0.894737              0.251796
# 3  0.894737             0.750000  ...                0.842105              1.000000
# 4  0.660819             0.166667  ...                0.789474              0.015258
#
# [5 rows x 20 columns]

# %% [markdown]
# ### Tranmsformación inversa del escalado para interpretación

# %%
df_cluster_1 = df_scaled.loc[[1,5,8,6,20]]
pd.DataFrame(scaler.inverse_transform(df_cluster_1.values))
# Out:
#      0          1     2     3     4   ...         15    16    17    18         19
# 0   8.0   1.000000   7.0   1.0   7.0  ...   9.000000   9.0   8.0   9.0   9.000000
# 1  13.0   6.423077   8.0  10.0   9.0  ...   5.000000   3.0  12.0  20.0  26.721673
# 2  14.0   8.000000   9.0  10.0  11.0  ...   1.000000  18.0  19.0  20.0   5.000000
# 3  17.0  13.000000  14.0  19.0  20.0  ...  20.000000  17.0  20.0  20.0  19.000000
# 4  15.0  10.000000  15.0  13.0  13.0  ...  11.423077  12.0  13.0  16.0  14.000000
#
# [5 rows x 20 columns]

# %% [markdown]
# 1. Flujo de datos:
#   - Limpieza de datos
#     - Remover ouliers
#     - Imputación
#   - Escalamiento de variables
#   - Modelamiento
#   - Escalamiento inverso de variables para interpretar

# %%
import plotly.graph_objects as go
import numpy as np

fig = go.Figure()
for index, column in df_scaled.iteritems():
    fig.add_trace(go.Box(y=column, name=index))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5f4a18ee-fc8f-45e1-acee-6517f735cc24" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5f4a18ee-fc8f-45e1-acee-6517f735cc24")) {
#                     Plotly.newPlot(
#                         '5f4a18ee-fc8f-45e1-acee-6517f735cc24',
#                         [{"name": "Iron Man", "type": "box", "y": [0.8421052631578947, 0.3684210526315789, 1.0, 0.894736842105263, 0.6608187134502914, 0.631578947368421, 0.8421052631578947, 0.47368421052631576, 0.6842105263157894, 0.7894736842105263, 0.736842105263158, 0.0, 0.5263157894736843, 0.736842105263158, 0.7894736842105263, 0.736842105263158, 0.10526315789473684, 0.6608187134502899, 0.42105263157894735, 0.894736842105263, 0.736842105263158, 0.894736842105263, 0.631578947368421, 0.894736842105263, 0.736842105263158, 0.8421052631578947, 0.8421052631578947, 0.6608187134502908, 0.3157894736842105, 0.47368421052631576]}, {"name": "The Incredible Hulk", "type": "box", "y": [0.9166666666666666, 0.0, 0.9999999999999999, 0.7499999999999999, 0.16666666666666669, 0.4519230769230725, 0.9999999999999999, 0.8333333333333333, 0.5833333333333333, 0.9999999999999999, 0.0, 0.0, 0.08333333333333333, 0.9166666666666666, 0.3333333333333333, 0.7499999999999999, 0.3333333333333333, 0.08333333333333333, 0.0, 0.7499999999999999, 0.7499999999999999, 0.7499999999999999, 0.08333333333333333, 0.0, 0.0, 0.45192307692307837, 0.4519230769230746, 0.4519230769230796, 0.08333333333333333, 0.5833333333333333]}, {"name": "Iron Man 2", "type": "box", "y": [0.7222222222222221, 0.33333333333333326, 0.2777777777777778, 1.0, 0.05555555555555555, 0.38888888888888884, 0.7222222222222221, 0.611111111111111, 0.4444444444444444, 0.5, 0.1111111111111111, 0.0, 0.22222222222222224, 0.22222222222222224, 0.2777777777777778, 0.611111111111111, 0.38888888888888884, 0.4827586206896879, 0.2777777777777778, 0.9444444444444444, 0.7777777777777777, 0.7222222222222221, 0.5, 0.611111111111111, 0.7222222222222221, 0.8333333333333333, 0.7777777777777777, 0.2777777777777778, 0.16666666666666666, 0.5]}, {"name": "Thor", "type": "box", "y": [0.7084487212358144, 0.12534616370744298, 0.4168974424716287, 0.8056324808238763, 0.2711218030895358, 0.5626730818537216, 1.0, 0.5140812020596905, 0.5626730818537216, 0.7570406010298453, 0.3197136828835668, 0.12534616370744298, 0.22252992329550486, 0.7084487212358144, 0.17393804350147393, 0.36830556267759773, 0.6112649616477525, 0.3688974824724133, 0.0, 0.5626730818537216, 0.7084487212358144, 0.5140812020596905, 0.36830556267759773, 0.17393804350147393, 0.3197136828835668, 0.7570406010298453, 0.22252992329550486, 0.36830556267759773, 0.22252992329550486, 0.46548932226565964]}, {"name": "Capit\u00e1n Am\u00e9rica: el primer vengador", "type": "box", "y": [0.5263157894736843, 0.3157894736842105, 0.5263157894736843, 0.21052631578947367, 0.21052631578947367, 0.42105263157894735, 1.0, 0.3684210526315789, 0.5263157894736843, 0.736842105263158, 0.42105263157894735, 0.0, 0.8421052631578947, 0.736842105263158, 0.47368421052631576, 0.21052631578947367, 0.42105263157894735, 0.805708769371561, 0.5263157894736843, 0.3684210526315789, 0.631578947368421, 0.5789473684210527, 0.21052631578947367, 0.631578947368421, 0.7894736842105263, 0.5143602805444736, 0.5789473684210527, 0.736842105263158, 0.3684210526315789, 0.894736842105263]}, {"name": "The Avengers", "type": "box", "y": [0.894736842105263, 0.3684210526315789, 0.9473684210526316, 0.7894736842105263, 0.47368421052631576, 0.8421052631578947, 1.0, 0.9473684210526316, 0.736842105263158, 1.0, 0.5263157894736843, 0.0, 0.736842105263158, 0.8421052631578947, 0.9473684210526316, 0.7894736842105263, 0.5789473684210527, 0.10526315789473684, 0.6842105263157894, 0.6842105263157894, 0.7894736842105263, 0.6842105263157894, 0.3684210526315789, 0.8421052631578947, 0.42105263157894735, 0.894736842105263, 0.8421052631578947, 0.8421052631578947, 0.631578947368421, 0.6842105263157894]}, {"name": "Iron Man 3", "type": "box", "y": [0.11259177735440848, 0.22518355470881696, 0.30024473961175596, 0.6380200716749814, 0.0, 0.4878977018691034, 0.33777533206322546, 0.22518355470881696, 0.18765296225734746, 0.22518355470881696, 0.15012236980587798, 0.0, 0.4878977018691034, 0.4128365169661644, 0.11259177735440848, 0.07506118490293898, 0.0, ...

# %%
ri = df_scaled.quantile(.75) - df_scaled.quantile(.25)
ls = df_scaled.quantile(.75) + (1.5 * ri )
ls
# Out:
# Iron Man                               1.276316
# The Incredible Hulk                    1.750000
# Iron Man 2                             1.388889
# Thor                                   1.145776
# Capitán América: el primer vengador    1.223684
# The Avengers                           1.217105
# Iron Man 3                             0.999124
# Thor: The Dark World                   1.340278
# Captain America: The Winter Soldier    1.664474
# Guardianes de la Galaxia               1.312500
# Avengers: Age of Ultron                1.427632
# Ant-Man                                1.222222
# Captain America: Civil War             1.447368
# Doctor Strange                         1.276316
# Guardianes de la Galaxia Vol. 2        1.414474
# Spider-Man: Homecoming                 1.177632
# Thor: Ragnarok                         1.135206
# Black Panther                          1.493421
# Avengers: Infinity War                 1.296053
# Ant-Man and The Wasp                   0.920853
# dtype: float64

# %%
li = df_scaled.quantile(.25) - (1.5 * ri )
li
# Out:
# Iron Man                               0.118421
# The Incredible Hulk                   -0.916667
# Iron Man 2                            -0.388889
# Thor                                  -0.311981
# Capitán América: el primer vengador   -0.144737
# The Avengers                           0.217105
# Iron Man 3                            -0.404315
# Thor: The Dark World                  -0.604167
# Captain America: The Winter Soldier   -0.388158
# Guardianes de la Galaxia               0.034722
# Avengers: Age of Ultron               -0.309211
# Ant-Man                               -0.111111
# Captain America: Civil War             0.078947
# Doctor Strange                         0.118421
# Guardianes de la Galaxia Vol. 2       -0.427632
# Spider-Man: Homecoming                -0.032895
# Thor: Ragnarok                         0.022783
# Black Panther                         -0.243421
# Avengers: Infinity War                 0.506579
# Ant-Man and The Wasp                  -0.097098
# dtype: float64

# %%
df_scaled2 = df_scaled.copy()
for key in li.keys():
    df_scaled2 = df_scaled2[df_scaled2[key] > li[key]]

# %%
df_scaled3 = df_scaled.copy()
for key in ls.keys():
    df_scaled3 = df_scaled3[df_scaled3[key] > ls[key]]

# %%
df_scaled3
# Out:
# Empty DataFrame
# Columns: [Iron Man, The Incredible Hulk, Iron Man 2, Thor, Capitán América: el primer vengador, The Avengers, Iron Man 3, Thor: The Dark World, Captain America: The Winter Soldier, Guardianes de la Galaxia, Avengers: Age of Ultron, Ant-Man, Captain America: Civil War, Doctor Strange, Guardianes de la Galaxia Vol. 2, Spider-Man: Homecoming, Thor: Ragnarok, Black Panther, Avengers: Infinity War, Ant-Man and The Wasp]
# Index: []

# %%
from scipy import stats
z_score = stats.zscore(df_scaled)
norm = stats.norm()
max_val = norm.ppf(.95)
df_bool = pd.DataFrame(z_score) < -max_val
df_scaled3 = df_mcu[df_bool.sum(axis=1) == 0]

# %%
import plotly.graph_objects as go
import numpy as np

fig = go.Figure()
for index, column in df_scaled3.iteritems():
    fig.add_trace(go.Box(y=column, name=index))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="97e9f5ae-f65a-40bb-a55f-9b8a248fed7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("97e9f5ae-f65a-40bb-a55f-9b8a248fed7d")) {
#                     Plotly.newPlot(
#                         '97e9f5ae-f65a-40bb-a55f-9b8a248fed7d',
#                         [{"name": "Iron Man", "type": "box", "y": [17.0, 20.0, 18.0, 13.0, 17.0, 16.0, 15.0, 15.0, 16.0, 15.0, 15.0, 18.0, 13.0, 17.0, null, 10.0]}, {"name": "The Incredible Hulk", "type": "box", "y": [12.0, 13.0, 10.0, null, 13.0, 13.0, 1.0, 12.0, 5.0, 10.0, 10.0, 10.0, 2.0, null, null, 8.0]}, {"name": "Iron Man 2", "type": "box", "y": [14.0, 6.0, 19.0, 8.0, 14.0, 10.0, 3.0, 5.0, 6.0, 12.0, 15.0, 14.0, 10.0, 16.0, 6.0, 10.0]}, {"name": "Thor", "type": "box", "y": [13.0, 7.0, 15.0, 10.0, 19.0, 14.0, 5.0, 13.0, 2.0, 6.0, 13.0, 9.0, 6.0, 14.0, 6.0, 8.0]}, {"name": "Capit\u00e1n Am\u00e9rica: el primer vengador", "type": "box", "y": [11.0, 11.0, 5.0, 9.0, 20.0, 15.0, 9.0, 15.0, 10.0, 5.0, 13.0, 12.0, 5.0, null, 15.0, 18.0]}, {"name": "The Avengers", "type": "box", "y": [18, 19, 16, 17, 20, 20, 11, 17, 19, 16, 16, 14, 8, 18, 17, 14]}, {"name": "Iron Man 3", "type": "box", "y": [4.0, 9.0, 18.0, 14.0, 10.0, 7.0, 5.0, 12.0, 4.0, 3.0, null, 16.0, 9.0, null, null, 12.0]}, {"name": "Thor: The Dark World", "type": "box", "y": [5.0, 5.0, 16.0, 12.0, 19.0, 7.0, 10.0, 3.0, 1.0, 2.0, null, 16.0, 3.0, 12.0, 12.0, 9.0]}, {"name": "Captain America: The Winter Soldier", "type": "box", "y": [6.0, 17.0, 8.0, 14.0, 20.0, 18.0, 18.0, 18.0, 13.0, 9.0, null, 18.0, 15.0, 11.0, 12.0, 14.0]}, {"name": "Guardianes de la Galaxia", "type": "box", "y": [16.0, 20.0, 18.0, 16.0, 20.0, 15.0, 14.0, 17.0, 15.0, 19.0, null, 16.0, 16.0, 18.0, 15.0, 8.0]}, {"name": "Avengers: Age of Ultron", "type": "box", "y": [17.0, 20.0, null, 14.0, 17.0, 13.0, 12.0, 10.0, 7.0, 11.0, 16.0, 13.0, 4.0, null, 17.0, 15.0]}, {"name": "Ant-Man", "type": "box", "y": [10.0, 17.0, null, 10.0, 19.0, 13.0, 8.0, 14.0, 14.0, 17.0, null, 12.0, 14.0, null, 18.0, 8.0]}, {"name": "Captain America: Civil War", "type": "box", "y": [19.0, 20.0, 18.0, 19.0, 20.0, 20.0, 18.0, 16.0, 18.0, 18.0, 14.0, 11.0, 12.0, 17.0, null, 18.0]}, {"name": "Doctor Strange", "type": "box", "y": [17.0, 10.0, null, 17.0, 20.0, 15.0, 16.0, 14.0, 17.0, 17.0, null, 19.0, 11.0, 14.0, 16.0, 15.0]}, {"name": "Guardianes de la Galaxia Vol. 2", "type": "box", "y": [7.0, 6.0, 16.0, 8.0, 20.0, 15.0, 19.0, 20.0, 3.0, null, null, 17.0, 18.0, 14.0, null, 11.0]}, {"name": "Spider-Man: Homecoming", "type": "box", "y": [6.0, 6.0, 10.0, 5.0, 20.0, 16.0, 20.0, 18.0, 12.0, 14.0, null, 9.0, 7.0, null, null, 14.0]}, {"name": "Thor: Ragnarok", "type": "box", "y": [10.0, 4.0, null, 3.0, 17.0, 13.0, 14.0, 18.0, 11.0, 14.0, 12.0, 17.0, 19.0, 12.0, 10.0, 13.0]}, {"name": "Black Panther", "type": "box", "y": [8.0, 17.0, null, 12.0, 20.0, 15.0, 17.0, 18.0, 8.0, 17.0, 13.0, 15.0, 20.0, null, 15.0, 15.0]}, {"name": "Avengers: Infinity War", "type": "box", "y": [20, 18, 17, 20, 20, 20, 16, 20, 20, 20, 16, 20, 17, 20, 17, 17]}, {"name": "Ant-Man and The Wasp", "type": "box", "y": [9.0, 8.0, null, null, 19.0, 14.0, 7.0, 16.0, 9.0, 13.0, 14.0, null, null, null, 18.0, 13.0]}],
#                         {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"marker": {"colorbar": {" ...

# %%
! pip install names
# Out:
# Collecting names
#   Downloading https://files.pythonhosted.org/packages/44/4e/f9cb7ef2df0250f4ba3334fbdabaa94f9c88097089763d8e85ada8092f84/names-0.3.0.tar.gz (789kB)
#      |████████████████████████████████| 798kB 3.4MB/s
# Building wheels for collected packages: names
#   Building wheel for names (setup.py) ... done
#   Created wheel for names: filename=names-0.3.0-cp36-none-any.whl size=803689 sha256=878f1206e1cd69a992843bf84f177b6d64af59b1d002790d5ef4a818bc257024
#   Stored in directory: /root/.cache/pip/wheels/f9/a5/e1/be3e0aaa6fa285575078fa2aafd9959b45bdbc8de8a6803aeb
# Successfully built names
# Installing collected packages: names
# Successfully installed names-0.3.0

# %%
import names 


peso = np.arange(20,80)
peso = np.random.choice(peso, 500)

talla = (peso * 1.1) + 100 
talla = talla + np.random.normal(loc=0, scale=3, size=len(talla))

nombres = [names.get_first_name() for x in np.arange(len(peso))]
np.random.seed(1)

fig = go.Figure(data=go.Scatter(x=talla, y=peso, mode='markers'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="10edbd48-2875-4fce-9329-3b16b479c0c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("10edbd48-2875-4fce-9329-3b16b479c0c1")) {
#                     Plotly.newPlot(
#                         '10edbd48-2875-4fce-9329-3b16b479c0c1',
#                         [{"mode": "markers", "type": "scatter", "x": [161.33555379633103, 166.41393419852645, 165.2006199380798, 163.37202360120637, 179.64326576903858, 157.6673388505144, 177.15108607022879, 140.076630692219, 189.94871082882412, 171.82706074497892, 164.892255030023, 181.66950266537023, 172.12572895860188, 168.49921549027314, 163.43981823295547, 154.5340158180481, 141.02650168516428, 138.1065009133601, 120.25385064182973, 161.72351879603684, 142.70686447908832, 128.84864123562085, 149.88417817959987, 131.8328507180404, 184.63372404723444, 127.80174141852306, 130.72909645595058, 137.49184859428937, 168.1694704790704, 154.55346410743113, 125.99840258981222, 184.89817141429438, 136.7723433490917, 130.4275460909018, 168.8089173157158, 129.6070741352415, 161.7054519839242, 146.26519451538377, 171.6739630980771, 164.9507074254447, 150.9146160415777, 178.51365228824264, 126.11191235601139, 139.44333970252274, 149.72611299470515, 156.347943228436, 150.50206042479658, 186.42912148971467, 130.00428524225472, 166.6824473491459, 168.61639461683285, 156.7095580033137, 155.02200539082378, 189.87233889634712, 168.41609262576844, 181.30968206218665, 139.67141866981018, 139.84476459945444, 163.39918097306452, 179.6127259640182, 171.19367241929592, 155.54932566982495, 157.95151324204494, 170.88794454551078, 121.57844050155768, 140.46186886151997, 145.87484772556385, 159.71864598685218, 140.71131056721774, 166.04446363476248, 128.58707729271146, 178.47907757603127, 179.0043027012192, 185.9426160568263, 144.96219874024982, 130.66326240842747, 181.44099566063662, 146.0014497169456, 133.46737634139905, 139.86418901796432, 165.3524750749572, 146.87282839576562, 117.73615730524, 174.7326867266008, 151.12848846789657, 145.5486048514922, 141.0345479482255, 165.37048710648136, 147.4984626894851, 160.90960404759937, 122.21503324899487, 129.4636994825775, 181.1284238783, 163.71695593544044, 166.39008292973378, 177.40422277175207, 168.7982633208897, 173.2785516527131, 177.38929114010165, 173.97477978876626, 127.50839442547826, 154.42527736015734, 122.19637013653396, 147.35992696238037, 135.05064045407195, 140.5086603580714, 130.15329434019438, 169.41518526804188, 158.16450120301027, 181.3406382211821, 165.92877358507798, 127.77639994263481, 123.11241650756989, 151.7775034202151, 178.1097181530841, 189.08702111228763, 167.47154015959842, 136.80166467068693, 162.90833453523686, 178.5486576675576, 131.2014109157206, 120.17290585515808, 161.98849286366402, 136.03104369725406, 192.73692708928274, 133.31330146418318, 169.36266662953759, 139.87109014031228, 136.63625606611154, 165.14311707771316, 154.3051016826971, 129.97968559405496, 144.85359774607124, 161.71039034190667, 176.6640189387301, 184.51987256277036, 158.78513913095702, 129.76760753830894, 182.8361628089058, 156.38357636519234, 134.53040299707666, 134.03802981478347, 175.61690094691627, 176.61712481154834, 125.11820003710346, 126.25969001285993, 142.40082817812802, 169.3303667963804, 162.66178736094196, 144.2390002112863, 143.55764499916765, 181.9027100422344, 162.83468040628094, 159.46832593933306, 169.65630509604173, 172.82015939951208, 126.29100312922472, 161.29160208312766, 155.0552550212304, 166.4519672076717, 140.1690782287377, 157.9358671238991, 126.73492874578345, 179.49994730782868, 129.04418866097137, 180.19865071152904, 179.2928191165392, 187.02584298481713, 180.402491122829, 182.8437328123982, 163.98516000067153, 144.65691571803103, 132.78527709018107, 125.53964283822238, 177.22588483922743, 141.4176280439035, 144.2861057524359, 139.79672288203804, 132.4804022983827, 184.8734654374114, 146.73630699391572, 133.914965888384, 174.0805597539343, 187.94651871432447, 155.21034150477698, 183.5017414201291, 134.22735040518003, 160.21627045521683, 162.95383491635548, 123.74986706606508, 175.85986709932195, 154.7224463781059, 147.68514204185985, 165.48571741196528, 189.45867363013406, 120.78998009417774, 139.04878235295217, 124.17118586820591, 122.91582274483767, 126.46400232491264,  ...

# %%
df_talla_peso = pd.DataFrame({'Nombre': nombres, 'Peso': peso, 'Talla': talla})
df_outliers = pd.DataFrame({'Nombre': ['Mario', 'Francisco'], 'Peso': [22, 80], 'Talla': [185, 130]})
df_talla_peso = pd.concat([df_talla_peso, df_outliers])
df_talla_peso = df_talla_peso.sample(frac=1).reset_index(drop=True)
df_talla_peso.head()
# Out:
#     Nombre  Peso       Talla
# 0   Melody    48  153.580679
# 1    Alice    36  134.757144
# 2  Colleen    79  186.429121
# 3    Wendy    50  159.718646
# 4    Dinah    54  154.707063

# %%
df_talla_peso.shape
# Out:
# (502, 3)

# %%
bins = [0, 100, 130, 150, 170, 200, 220]
cats = pd.cut(df_talla_peso['Talla'], bins)
cats.name = 'Talla_categ'
pd.concat([df_talla_peso, cats], axis=0)
# Out:
#       Nombre  Peso       Talla           0
# 0     Melody  48.0  153.580679         NaN
# 1      Alice  36.0  134.757144         NaN
# 2    Colleen  79.0  186.429121         NaN
# 3      Wendy  50.0  159.718646         NaN
# 4      Dinah  54.0  154.707063         NaN
# ..       ...   ...         ...         ...
# 497      NaN   NaN         NaN  (100, 130]
# 498      NaN   NaN         NaN  (170, 200]
# 499      NaN   NaN         NaN  (100, 130]
# 500      NaN   NaN         NaN  (170, 200]
# 501      NaN   NaN         NaN  (130, 150]
#
# [1004 rows x 4 columns]

# %%
generos = np.array(['M', 'F', 'ND'])
df1 = pd.DataFrame({'Genero': np.random.choice(generos, 20)})
df1
# Out:
#    Genero
# 0       M
# 1      ND
# 2       F
# 3      ND
# 4       F
# 5      ND
# 6      ND
# 7       F
# 8       M
# 9       M
# 10      F
# 11      F
# 12     ND
# 13      F
# 14      F
# 15     ND
# 16      F
# 17      F
# 18     ND
# 19     ND

# %%
pd.get_dummies(df1['Genero'])
# Out:
#     F  M  ND
# 0   0  1   0
# 1   0  0   1
# 2   1  0   0
# 3   0  0   1
# 4   1  0   0
# 5   0  0   1
# 6   0  0   1
# 7   1  0   0
# 8   0  1   0
# 9   0  1   0
# 10  1  0   0
# 11  1  0   0
# 12  0  0   1
# 13  1  0   0
# 14  1  0   0
# 15  0  0   1
# 16  1  0   0
# 17  1  0   0
# 18  0  0   1
# 19  0  0   1

# %%
df_talla_peso.to_excel('Talla_peso.xlsx')

# %%
df_talla_peso.to_csv('Talla_peso.csv', index=False)

# %%
df_talla_peso.to_sql
# Out:
# <bound method NDFrame.to_sql of        Nombre  Peso       Talla
# 0      Melody    48  153.580679
# 1       Alice    36  134.757144
# 2     Colleen    79  186.429121
# 3       Wendy    50  159.718646
# 4       Dinah    54  154.707063
# ..        ...   ...         ...
# 497   Janelle    30  125.658447
# 498      Erin    71  179.004303
# 499  Nicholas    22  125.308335
# 500    Steven    78  183.642049
# 501    George    46  146.265195
#
# [502 rows x 3 columns]>

# %%
! wget https://www.dropbox.com/s/wq48iaeeahwqau4/Iris_faltantes.xlsx
! wget https://www.dropbox.com/s/xz2feavbubiu6dw/Iris.xlsx
# Out:
# --2020-09-27 05:52:16--  https://www.dropbox.com/s/wq48iaeeahwqau4/Iris_faltantes.xlsx
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/wq48iaeeahwqau4/Iris_faltantes.xlsx [following]
# --2020-09-27 05:52:17--  https://www.dropbox.com/s/raw/wq48iaeeahwqau4/Iris_faltantes.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com/cd/0/inline/BAKBy0-IkmSN6wnRa1piql7R6UBsXoo1VI6J1tgFQWZqIHMsXwIuKe3UvOQ85okWTy7YZCpRR8TMpC2xtC1VzgSDBDN1DVGhVWhsYpleCGN506PV3yR2Oi6XBjfJNY2C7F4/file# [following]
# --2020-09-27 05:52:17--  https://uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com/cd/0/inline/BAKBy0-IkmSN6wnRa1piql7R6UBsXoo1VI6J1tgFQWZqIHMsXwIuKe3UvOQ85okWTy7YZCpRR8TMpC2xtC1VzgSDBDN1DVGhVWhsYpleCGN506PV3yR2Oi6XBjfJNY2C7F4/file
# Resolving uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com (uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com (uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BALdohTOm7XgWdgmqEe1QzMqNxLDxukQhNkQJhIaInrPUdiNHC4owP9yhqyyAihRxQRlfz23Ls-3vdNfaE5xaU7MLjolmJIfz4YwL-USOU0pdEdVvngAhQiXo50N61cxmC9kz-s6smP292YOfxnaI8LTTilqRqRrtRceEgo7vHZJw0tkLw7Br9rvicu7W-7_h2b7FnBJUv8Cra7K8x7pd0Z2EnzlAkXspAlkMgbKHNp5yEy3jgzAUin7JWxacVlcRbFfxTbH0mOksmT50kXi0qQCr0R4ydZcxt38nkHS2rJXrpuAwESmnr_D6IOcoBHU1DBIkTsSOz0-G2LlRDm8QQwNX8gkxizYI5EYkQx4SpmnQg/file [following]
# --2020-09-27 05:52:17--  https://uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com/cd/0/inline2/BALdohTOm7XgWdgmqEe1QzMqNxLDxukQhNkQJhIaInrPUdiNHC4owP9yhqyyAihRxQRlfz23Ls-3vdNfaE5xaU7MLjolmJIfz4YwL-USOU0pdEdVvngAhQiXo50N61cxmC9kz-s6smP292YOfxnaI8LTTilqRqRrtRceEgo7vHZJw0tkLw7Br9rvicu7W-7_h2b7FnBJUv8Cra7K8x7pd0Z2EnzlAkXspAlkMgbKHNp5yEy3jgzAUin7JWxacVlcRbFfxTbH0mOksmT50kXi0qQCr0R4ydZcxt38nkHS2rJXrpuAwESmnr_D6IOcoBHU1DBIkTsSOz0-G2LlRDm8QQwNX8gkxizYI5EYkQx4SpmnQg/file
# Reusing existing connection to uc4d07bfceee7f9a8b29f4bc9b0c.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8632 (8.4K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Iris_faltantes.xlsx’
#
# Iris_faltantes.xlsx 100%[===================>]   8.43K  --.-KB/s    in 0s
#
# 2020-09-27 05:52:18 (30.6 MB/s) - ‘Iris_faltantes.xlsx’ saved [8632/8632]
#
# --2020-09-27 05:52:18--  https://www.dropbox.com/s/xz2feavbubiu6dw/Iris.xlsx
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/xz2feavbubiu6dw/Iris.xlsx [following]
# --2020-09-27 05:52:18--  https://www.dropbox.com/s/raw/xz2feavbubiu6dw/Iris.xlsx
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com/cd/0/inline/BAJden3PgQHJ8HZ4mowJEL3Hdov1Zo-7o_bLiDweREsfsVXZuO5JL02DsztIiQOuVpR4ot9UEqIeE97vV_x6gOtVPiLuW4J4IKL5RjpfbmxTimyjUR4JFMac_scgz6Q5KXY/file# [following]
# --2020-09-27 05:52:18--  https://uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com/cd/0/inline/BAJden3PgQHJ8HZ4mowJEL3Hdov1Zo-7o_bLiDweREsfsVXZuO5JL02DsztIiQOuVpR4ot9UEqIeE97vV_x6gOtVPiLuW4J4IKL5RjpfbmxTimyjUR4JFMac_scgz6Q5KXY/file
# Resolving uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com (uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com (uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BAJnDcRx1KsSzk9910UfBt4dsRblN8Jc-xZNBBcPAkP6uRr10tFEzQZgYJCaUSHt4MAUu0zRLNGQEMsf6KCorPSYsHxkKoVXHwy0jYNzgtnwrJFYz--Rnhgcy0BPuP6fAb3O53Dh9FMnZNr5qbBToDje21iJ48tAjheu2ryiPw2muppIMTEYfjH1mW56E5lRj8Nm0Bl3DZ0pfQXOWmz2GsthHOxdojVY32ymfQgjvGhcj9n-_10rjKJx8qVLRtqgsgx32BuknR2PisZ6EZT8sMn5VnX3gxWtYrraYE8zVyZGZk_kk-6X6o03Lh7-bXvXB_y_w37YE6M05Q-JDOGoajVda7gMxU4cQHthzDzGXZ2Mfg/file [following]
# --2020-09-27 05:52:19--  https://uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com/cd/0/inline2/BAJnDcRx1KsSzk9910UfBt4dsRblN8Jc-xZNBBcPAkP6uRr10tFEzQZgYJCaUSHt4MAUu0zRLNGQEMsf6KCorPSYsHxkKoVXHwy0jYNzgtnwrJFYz--Rnhgcy0BPuP6fAb3O53Dh9FMnZNr5qbBToDje21iJ48tAjheu2ryiPw2muppIMTEYfjH1mW56E5lRj8Nm0Bl3DZ0pfQXOWmz2GsthHOxdojVY32ymfQgjvGhcj9n-_10rjKJx8qVLRtqgsgx32BuknR2PisZ6EZT8sMn5VnX3gxWtYrraYE8zVyZGZk_kk-6X6o03Lh7-bXvXB_y_w37YE6M05Q-JDOGoajVda7gMxU4cQHthzDzGXZ2Mfg/file
# Reusing existing connection to uc02399c94cc5f891f2ee53365a6.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 8725 (8.5K) [application/vnd.openxmlformats-officedocument.spreadsheetml.sheet]
# Saving to: ‘Iris.xlsx’
#
# Iris.xlsx           100%[===================>]   8.52K  --.-KB/s    in 0s
#
# 2020-09-27 05:52:19 (157 MB/s) - ‘Iris.xlsx’ saved [8725/8725]

# %%
import pandas as pd
iris = pd.read_excel('Iris.xlsx')
iris_faltantes = pd.read_excel('Iris_faltantes.xlsx')

# %%
iris_faltantes
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           NaN          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          NaN     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           NaN          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_1 = pd.DataFrame({'a':[1,2], 'b':[3,4]})
df_1
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df_2 = pd.DataFrame({'a':[5,6], 'b':[7,8]})
df_2
# Out:
#    a  b
# 0  5  7
# 1  6  8

# %%
np.sum(np.abs(df_1.values - df_2.values))
# Out:
# 16
