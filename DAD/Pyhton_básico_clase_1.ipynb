# %% [markdown]
# <a href="https://colab.research.google.com/github/gtzambranop/UN_2020_2/blob/DAD%2Fweek_4/DAD/Pyhton_b%C3%A1sico_clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **"Pyhton Básico"**
#
# * **Profesor:** Francisco Javier Ospina Salazar
# * **Monitoras:**
#   - Diana Carolina Sanchez Perez
#   - Guiselle Tatiana Zambrano Penagos
# * **Fechas:**
#   - Inicio: 2020-09-12
#   - Final: 2020-09-29
# * [Presentacióón del curso](http://ospinafrancisco.com/)

# %% [markdown]
# # Recursos adicionales

# %% [markdown]
# * [Nvidia GauGAN](https://www.youtube.com/watch?v=OGGjXG562WU)
# * [whichfaceisreal](https://www.whichfaceisreal.com/)
# * [Creating Presentations with Jupyter Notebook](https://www.blog.pythonlibrary.org/2018/09/25/creating-presentations-with-jupyter-notebook/)

# %% [markdown]
# # Introducción

# %% [markdown]
# ## ¿Qué es python?
#
# * Python es un lenguage de programación orientado a objetos.
# * Es interpretado, lo cuál implica que debe tenerse python instalado para poder ejecutar programas escritos en python.
# * A diferencia de R no fue creado para el análisis de datos, aunque es uno de sus puntos mas fuertes en la actualidad.
# * Tiene una sintaxis increiblemente noble, lo cual lo convierte en una herramienta con una curva de aprendizaje muy suave.

# %% [markdown]
# ## ¿Qué es una sintaxis noble?
#
# ```java
# // Hola mundo en JAVA
#
# package hola_mundo;
# public class hola_mundo {
#
#     public static void main(String[] args) {
#         System.out.println("Hola mundo");
#     }
# }
# ```
#
# ```c
# // Hola mundo en C++
#
# #include <iostream>
# using namespace std;
#
# int main() {
#     cout << "Hola Mundo" << endl;
#     return 0;
# }
# ```

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %% [markdown]
# ## ¿Por qué es usado Python para analizar los datos?
#
# * El salto de Python como lenguaje de datos se dió con la creación de múltiples librerías enfocadas al análisis de datos: Scipy, Numpy, Pandas, Matplotlib, [Plotly](https://plotly.com/), scikit-learn.
# * Recientemente se ha convertido en el lenguaje por excelencia para temas de Deep Learning, con la llegada de librerías como Tensorflow, Keras, Theano, Pythorch. ([Top 23 Deep Learning](https://www.kdnuggets.com/2017/10/ranking-popular-deep-learning-libraries-data-science.html)).
# * Es uno de los lenguajes de programación para los cuales Apache Spark tiene un API ([API python](https://spark.apache.org/docs/latest/api/python/index.html)).
#
# * Grandes empresas en el mundo apelan a él para el análisis de datos: Google, Facebook, Instagram, Airbnb, Spotify y Netflix entre otros. Esto tiene como consecuencia el desarrollo de librerías para uso interno que luego son liberadas.
#   * [Tensorflow](https://www.tensorflow.org/)(Google)
#   * [Airflow](https://airflow.apache.org/) (Airbnb)
#   * [Prophet](https://facebook.github.io/prophet/) (Facebook)

# %% [markdown]
# ## Python vs R ¿Cuál es mejor?
#
# * **Python y R no son enemigos**
# * No hay uno que en general sea mejor que el otro
# * Son excelentes complementos y cada uno tiene su enfoque puntual.
#   - Python
#       * Se entiende mejor con Deep Learning y Big Data.
#       * Es de proposito general.
#       * Tiene un mejor gestionamiento de memoria.
#   - R
#       * Se en tiende mejor con temas estríctamente estadísticos.
#       * Para modelamiento de datos todo viene empaquetado dentro. de el "objeto" resultado.

# %% [markdown]
# ## ¿Dónde conseguir ayuda para Python?
#
# * [Documentación oficial](https://www.python.org/doc/)
# * [DataCamp](https://www.python.org/doc/)
# * [Ebook Fundation](https://ebookfoundation.github.io/free-programming-books/) - [Github (EF)](https://github.com/EbookFoundation/free-programming-books)
# * [StackOverflow](https://es.stackoverflow.com/?tags=python)

# %% [markdown]
# ## ¿Cómo instalar Python? (Vía clásica I)
#
# * Ir a la url https://www.python.org/
# * Ir la sección "Downloads" -> "All releases" -> "Buscar Python 3.8.5 -> "Descargarlo e instalarlo"
# * Instalar PIP (Sistema de gestión de paquetes) desde https://pip.pypa.io/en/stable/installing/

# %% [markdown]
# ## Entornos para trabajar con Python
# * Descargar algún IDE para trabajar con Python:
#     * Atom. https://atom.io/
#     * Sublime text. https://www.sublimetext.com/
#     * Visual Studio Code. https://code.visualstudio.com/
#     * Spyder. https://www.spyder-ide.org/
#     * Pycharm. https://www.jetbrains.com/pycharm/
#     * Jupyter. https://jupyter.org/

# %% [markdown]
# ## ¿Qué es Anaconda?
#
# * Es un framework de Python y R orientado a la ciencia de datos.
# * Permite el uso de múltiples entornos lo cual es muy útil si se trabaja en múltiples proyectos simultaneamente.
# * Recien instalado provee alrededor de 250 modulos de Pyhton listos para usar.

# %% [markdown]
# # Workshop instalación Anaconda, sus funcionalidades y Google collab

# %% [markdown]
# ## ¿Cómo instalar Python? (Vía anaconda)
# * Ir a la url https://www.anaconda.com/distribution/
# * Ir a la sección de "Anaconda Installers"
# * Descargar acaconda basada en Python 3.8
# * Instalar anaconda

# %% [markdown]
# ## Funcionamiendo de Anaconda
#
# * Anaconda navigator
# * Entornos en Anaconda (Python y R)

# %% [markdown]
# ## Funcionamiento Jupyter
#
# * Modos
# * Tipos de celdas:
#   * Markdown ([Ayuda markdown](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet))
#   * Código
#     * Input
#     * Output
#     * Invocar el terminal del sistema operativo con !
#   * Ayuda de funciones en Jupyter

# %% [markdown]
# ## Hacer presentaciones web con Python y Jupyter
#
# * Convertir un notebook en slideshow
# * Configurar cada "Slide Type"
# * Compilar el notebook con "! jupyter nbconvert notebook.ipynb --to slides"
# * Abrir la presentación en un navegador web

# %% [markdown]
# ## Instalación de modulos (librerías o paquetes)
#
# * Vía Terminal de Anaconda (pip y conda)
# * Vía Notebook de Jupyter (pip y conda)
# * Carga de módulos en Python

# %% [markdown]
# ## Google Collab
#
# * Acceder al siguiente [notebook](https://colab.research.google.com/drive/1ElVb902r5LLopis3_6A2O0HXjl1Xt8xc)
# * Funcionamiento
# * Ayuda con errores
# * Procesamiento basado en GPU y TPU

# %% [markdown]
# # Carga de datos en Python

# %% [markdown]
# ## Descarga de conjuntos de datos

# %%
# !ls

# %%
# borrar todos los archivos
# !rm -r *
# Out:
# rm: cannot remove '*': No such file or directory

# %%
! wget https://www.dropbox.com/s/j3hyentgujb3py1/Boston_Housing.csv
! wget https://www.dropbox.com/s/9km9rc74nfr04rp/Boston_Housing.txt
! wget https://www.dropbox.com/s/0tbroy3xlzl7y30/Boston_Housing.dta
! wget https://www.dropbox.com/s/w1nl5eb3nle21oi/Sabana%20general%20ejercicio.sav
! wget https://www.dropbox.com/s/mpt53p35roeoxqd/PRICING.sav
! wget https://www.dropbox.com/s/8bix0evcsd6mnrv/Boston_Housing.xls
# Out:
# --2020-09-12 16:25:46--  https://www.dropbox.com/s/j3hyentgujb3py1/Boston_Housing.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.1, 2620:100:6030:1::a27d:5001
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/j3hyentgujb3py1/Boston_Housing.csv [following]
# --2020-09-12 16:25:47--  https://www.dropbox.com/s/raw/j3hyentgujb3py1/Boston_Housing.csv
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com/cd/0/inline/A_S1V0U06WBU43cc-JiTR1b7QUSvSOAyhTAT-utL3tG26a_Ry7Y8_br2BwUg2kuNWCZSTmLwmSTZ0lG-wevKUtEJt5tNR2u6hTkEmYrOaGsDfNjNBI3jtNHKF3hMBGp9y4w/file# [following]
# --2020-09-12 16:25:47--  https://ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com/cd/0/inline/A_S1V0U06WBU43cc-JiTR1b7QUSvSOAyhTAT-utL3tG26a_Ry7Y8_br2BwUg2kuNWCZSTmLwmSTZ0lG-wevKUtEJt5tNR2u6hTkEmYrOaGsDfNjNBI3jtNHKF3hMBGp9y4w/file
# Resolving ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com (ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6030:15::a27d:500f
# Connecting to ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com (ucdfb391ddd9a3711515316e3ea0.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34695 (34K) [text/plain]
# Saving to: ‘Boston_Housing.csv’
#
# Boston_Housing.csv  100%[===================>]  33.88K  --.-KB/s    in 0.06s
#
# 2020-09-12 16:25:47 (586 KB/s) - ‘Boston_Housing.csv’ saved [34695/34695]
#
# --2020-09-12 16:25:47--  https://www.dropbox.com/s/9km9rc74nfr04rp/Boston_Housing.txt
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.1, 2620:100:6030:1::a27d:5001
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/9km9rc74nfr04rp/Boston_Housing.txt [following]
# --2020-09-12 16:25:48--  https://www.dropbox.com/s/raw/9km9rc74nfr04rp/Boston_Housing.txt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://u
# --2020-09-12 16:25:56--  https://uc4ad7b77e797f29622c11f5d98f.dl.dropboxusercontent.com/cd/0/inline2/A_RiQDvpSaKQifOtQaf5pl7V1VQ1NXLkZUMRYJp_oPp8gEas7xDv-vbFb6SGWSz3nrcv4MzolofbddNHUwrmRucW864UfkiPEmCjpp-NswzDvKHOpxTbWIjlge9wX9MEZC8dIqxAhMTPqruWN41pVjkuNOG9q8cYIzZHH7v8nMznhSk3MUURj5jvkVmaPHqnHttWq1KIC9npa4EDJWvUTny7rnJ2dDmEbJTr2RnacQhJXuxX7yt5NBCZsVy9hUFYkad3Lge7wYpfRo_0LzMExaMVN8zNb4-hId32X0AGWWywKbA7lbnOOpkdo2GsMKnEQ7ANuQUBRAyR5ZtWvyz_tvPx9gBLuvJC2-3aGY9Psc4lcw/file
# Reusing existing connection to uc4ad7b77e797f29622c11f5d98f.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 109056 (106K) [application/vnd.ms-excel]
# Saving to: ‘Boston_Housing.xls’
#
# Boston_Housing.xls  100%[===================>] 106.50K  --.-KB/s    in 0.1s
#
# 2020-09-12 16:25:56 (967 KB/s) - ‘Boston_Housing.xls’ saved [109056/109056]

# %% [markdown]
# ## Visualización de archivos en el directorio

# %%
! ls
# Out:
#  Boston_Housing.csv   Boston_Housing.xls	      sample_data
#  Boston_Housing.dta   PRICING.sav
#  Boston_Housing.txt  'Sabana general ejercicio.sav'

# %% [markdown]
# ## Ver primeras 5 lineas de un archivo

# %%
! head -n 5  Boston_Housing.csv
# Out:
# CRIM;ZN;INDUS;CHAS;NOX;RM;AGE;DIS;RAD;TAX;PTRATIO;B;LSTAT;MEDV
# 0,00632;18;2,31;0;0,538;6,575;65,2;4,09;1;296;15,3;396,9;4,98;24
# 0,02731;0;7,07;0;0,469;6,421;78,9;4,9671;2;242;17,8;396,9;9,14;21,6
# 0,02729;0;7,07;0;0,469;7,185;61,1;4,9671;2;242;17,8;392,83;4,03;34,7
# 0,03237;0;2,18;0;0,458;6,998;45,8;6,0622;3;222;18,7;394,63;2,94;33,4

# %% [markdown]
# ## Carga de archivo CSV

# %%
import pandas as pd

df = pd.read_csv('Boston_Housing.csv', sep=';')
df.head()
# Out:
#       CRIM  ZN INDUS  CHAS    NOX     RM  ... RAD  TAX  PTRATIO       B LSTAT  MEDV
# 0  0,00632  18  2,31     0  0,538  6,575  ...   1  296     15,3   396,9  4,98    24
# 1  0,02731   0  7,07     0  0,469  6,421  ...   2  242     17,8   396,9  9,14  21,6
# 2  0,02729   0  7,07     0  0,469  7,185  ...   2  242     17,8  392,83  4,03  34,7
# 3  0,03237   0  2,18     0  0,458  6,998  ...   3  222     18,7  394,63  2,94  33,4
# 4  0,06905   0  2,18     0  0,458  7,147  ...   3  222     18,7   396,9  5,33  36,2
#
# [5 rows x 14 columns]

# %%
! head -n 5 Boston_Housing.txt
# Out:
# CRIM|ZN|INDUS|CHAS|NOX|RM|AGE|DIS|RAD|TAX|PTRATIO|B|LSTAT|MEDV
# 0,00632|18|2,31|0|0,538|6,575|65,2|4,09|1|296|15,3|396,9|4,98|24
# 0,02731|0|7,07|0|0,469|6,421|78,9|4,9671|2|242|17,8|396,9|9,14|21,6
# 0,02729|0|7,07|0|0,469|7,185|61,1|4,9671|2|242|17,8|392,83|4,03|34,7
# 0,03237|0|2,18|0|0,458|6,998|45,8|6,0622|3|222|18,7|394,63|2,94|33,4

# %% [markdown]
# ## Carga de archivo txt

# %%
df = pd.read_csv('Boston_Housing.txt', sep='|')
df.head()
# Out:
#       CRIM  ZN INDUS  CHAS    NOX     RM  ... RAD  TAX  PTRATIO       B LSTAT  MEDV
# 0  0,00632  18  2,31     0  0,538  6,575  ...   1  296     15,3   396,9  4,98    24
# 1  0,02731   0  7,07     0  0,469  6,421  ...   2  242     17,8   396,9  9,14  21,6
# 2  0,02729   0  7,07     0  0,469  7,185  ...   2  242     17,8  392,83  4,03  34,7
# 3  0,03237   0  2,18     0  0,458  6,998  ...   3  222     18,7  394,63  2,94  33,4
# 4  0,06905   0  2,18     0  0,458  7,147  ...   3  222     18,7   396,9  5,33  36,2
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Carga de archivo de STATA

# %%
df = pd.read_stata('Boston_Housing.dta')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# ## Carga de archivo de Excel

# %%
df = pd.read_excel('Boston_Housing.xls')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# **Nota:** Al leer archivos de excel puede surgir el siguiente error
#
# ImportError: Missing optional dependency 'xlrd'. Install xlrd >= 1.0.0 for Excel support Use pip or conda to install xlrd.
#
# se solventa con: `! pip install xlrd`

# %% [markdown]
# ## Carga de archivo de SPSS

# %%
! pip install pyreadstat
# Out:
# Collecting pyreadstat
#   Downloading https://files.pythonhosted.org/packages/b2/fc/d9238d4aabb8ae1c7e7ce1b71b897536420395b310e73949221f0dc14500/pyreadstat-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 2.7MB/s
# Requirement already satisfied: pandas>0.24.0 in /usr/local/lib/python3.6/dist-packages (from pyreadstat) (1.0.5)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>0.24.0->pyreadstat) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>0.24.0->pyreadstat) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>0.24.0->pyreadstat) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>0.24.0->pyreadstat) (1.15.0)
# Installing collected packages: pyreadstat
# Successfully installed pyreadstat-1.0.2

# %%
pd.read_spss('Sabana general ejercicio.sav')
# Out:
#                   Barrio     Genero  ... PersonasCargoNum  CuantosHijosNum
# 0             san isidro   Femenino  ...               NO                1
# 1             el pesebre  Masculino  ...               NO                1
# 2               galerias  Masculino  ...               NO                1
# 3              san mateo   Femenino  ...               NO                1
# 4     villa de los alpes   Femenino  ...               NO                1
# ...                  ...        ...  ...              ...              ...
# 1252            san jose   Femenino  ...               SI                3
# 1253              nievez   Femenino  ...               SI                3
# 1254           univerzal   Femenino  ...               SI                3
# 1255     esperanza 7 etp   Femenino  ...               SI          4 o más
# 1256            San Jose  Masculino  ...               SI          4 o más
#
# [1257 rows x 135 columns]

# %% [markdown]
# ## Carga directamente de una base de datos SQL I

# %%
!  pip install sqlalchemy psycopg2
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.6/dist-packages (1.3.19)
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.6/dist-packages (2.7.6.1)

# %% [markdown]
# ## Carga directamente de una base de datos SQL II

# %%
from sqlalchemy import create_engine

db_credentials = 'postgres://usuariodiplomado:usuario2020@52.12.136.102:5432/diplomado2020'
db = create_engine(db_credentials)
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
df = pd.read_sql_query('SELECT * FROM boston_housing limit 10', con=db)
df
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
# 5  0.02985   0.0   2.18     0  0.458  ...  222     18.7  394.12   5.21  28.7
# 6  0.08829  12.5   7.87     0  0.524  ...  311     15.2  395.60  12.43  22.9
# 7  0.14455  12.5   7.87     0  0.524  ...  311     15.2  396.90  19.15  27.1
# 8  0.21124  12.5   7.87     0  0.524  ...  311     15.2  386.63  29.93  16.5
# 9  0.17004  12.5   7.87     0  0.524  ...  311     15.2  386.71  17.10  18.9
#
# [10 rows x 14 columns]
